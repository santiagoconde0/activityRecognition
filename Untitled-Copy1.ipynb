# %% [markdown]
# # **Project Activity Recognition from sensors**
#
# *Santiago Suarez Conde*<br>
# *Alejandro*<br>
# *Juliana Jaime*

# %% [markdown]
# ## Label 0 - Other activities
# ## Label 1 - Stand Up
# ## Label 2 - Grab the gun
# ## Label 3 - Point
# ## Label 4 - Shoot
# ## Label 5 - Load

# %% [markdown]
# ## Code:

# %% [markdown]
# `Libreries`

# %%
import numpy as np
import pandas as pd
import seaborn as sns
from scipy import stats
from scipy.stats import mode

# %% [markdown]
# `Paths`

# %%
#Headers
header_path = 'C:\\Users\\s7277028\\Documents\\ARSSD\\project\\header.csv' 
main_path = 'C:\\Users\\s7277028\\Documents\\ARSSD\\project'
users = range(1,5)
trials = range(0,6)
all_data = pd.DataFrame()

# %% [markdown]
# `Read files`

# %%
header=pd.read_csv(header_path, names=['column',''])['column'].values

# %% [markdown]
# ### Sensors

# %%
print('\n'.join(map(str, header)))
# Out:
# accelerometerAccelerationX
# accelerometerAccelerationY
# accelerometerAccelerationZ
# accelerometerTimestamp_sinceReboot
# activity
# activityActivityConfidence
# activityActivityStartDate
# activityTimestamp_sinceReboot
# altimeterPressure
# altimeterRelativeAltitude
# altimeterReset
# altimeterTimestamp_sinceReboot
# avAudioRecorderAveragePower
# avAudioRecorderPeakPower
# batteryLevel
# batteryState
# deviceID
# deviceOrientation
# gyroRotationX
# gyroRotationY
# gyroRotationZ
# gyroTimestamp_sinceReboot
# identifierForVendor
# IP_en0
# IP_pdp_ip0
# label
# locationAltitude
# locationCourse
# locationFloor
# locationHeadingAccuracy
# locationHeadingTimestamp_since1970
# locationHeadingX
# locationHeadingY
# locationHeadingZ
# locationHorizontalAccuracy
# locationLatitude
# locationLongitude
# locationMagneticHeading
# locationSpeed
# locationTimestamp_since1970
# locationTrueHeading
# locationVerticalAccuracy
# loggingTime
# logSampleNr
# magnetometerTimestamp_sinceReboot
# magnetometerX
# magnetometerY
# magnetometerZ
# motionAttitudeReferenceFrame
# motionGravityX
# motionGravityY
# motionGravityZ
# motionMagneticFieldCalibrationAccuracy
# motionMagneticFieldX
# motionMagneticFieldY
# motionMagneticFieldZ
# motionPitch
# motionQuaternionW
# motionQuaternionX
# motionQuaternionY
# motionQuaternionZ
# motionRoll
# motionRotationRateX
# motionRotationRateY
# motionRotationRateZ
# motionTimestamp_sinceReboot
# motionUserAccelerationX
# motionUserAccelerationY
# motionUserAccelerationZ
# motionYaw
# pedometerAverageActivePace
# pedometerCurrentCadence
# pedometerCurrentPace
# pedometerDistance
# pedometerEndDate
# pedometerFloorsAscended
# pedometerFloorsDescended
# pedometerNumberOfSteps
# pedometerStartDate

# %%
for trial in trials:
    filePath = main_path + "\\data\\User1\\T"+str(trial)+".csv"
    sadl1 = pd.read_csv(filePath, sep=',', header=0)
    data = sadl1.iloc[:, :79]
    data=data[data.columns[np.r_[0:1,21:24]]]
    labels = sadl1.iloc[:,78]

    #find and remove rows with all nulls
    idx=data.index[data.isnull().all(1)]
    data = data[~data.index.isin(idx)]
    labels = labels[~labels.index.isin(idx)]
    labels.value_counts()

    # #fill missing values
    data = data.fillna(method='ffill',axis=1)
    data['user'] = 1
    data['trial'] = trial

    columns = data.columns[~data.columns.isin(['user', 'trial', 'loggingTime'])]
    filtered_data = data[columns].rolling(5).median()
    filtered_data = filtered_data.fillna(method='ffill',axis=1)
    filtered_data['loggingTime'] = data.loggingTime
    # #segmentation

    filtered_data['time']=pd.to_datetime(data.loggingTime, unit='s')
    filtered_data.index=filtered_data.time
    keep = filtered_data.time.dt.microsecond/1000 %500
    keep = keep - keep.shift() < 0

    means = filtered_data[columns].rolling('0.5S').mean()[keep]
    means.columns = [str(col) + '_mean' for col in means.columns]
    variances = filtered_data[columns].rolling('0.5S').var()[keep]
    variances.columns = [str(col) + '_var' for col in variances.columns]

    labels.index = filtered_data.time
    mode_labels = labels.rolling('1S').apply(lambda x:mode(x)[0])[keep]

    #all features
    all_features = pd.concat([means, variances], axis=1)
    all_features['label'] = mode_labels 
    all_features['user'] = 1
    all_features['trial'] = trial
    all_data = pd.concat([all_data, all_features])
# Out:
# C:\Users\s7277028\AppData\Local\Continuum\anaconda3\lib\site-packages\ipykernel_launcher.py:36: FutureWarning: Currently, 'apply' passes the values as ndarrays to the applied function. In the future, this will change to passing it as Series objects. You need to specify 'raw=True' to keep the current behaviour, and you can pass 'raw=False' to silence this warning

# %%
sns.lineplot(x='loggingTime', y='accelerometerAccelerationX', data=data[:10000])
sns.lineplot(x='loggingTime', y='accelerometerAccelerationX', data=filtered_data.iloc[:10000])

# %%
sns.lineplot(x='loggingTime', y='accelerometerAccelerationY', data=data[:10000])
sns.lineplot(x='loggingTime', y='accelerometerAccelerationY', data=filtered_data.iloc[:10000])

# %%
sns.lineplot(x='loggingTime', y='accelerometerAccelerationZ', data=data[:10000])
sns.lineplot(x='loggingTime', y='accelerometerAccelerationZ', data=filtered_data.iloc[:10000])

# %%
all_data
# Out:
#                                accelerometerAccelerationX_mean  \
# time
# 2019-06-22 20:06:20.514400005                        -0.762470
# 2019-06-22 20:06:21.001487970                        -0.766411
# 2019-06-22 20:06:21.507235050                        -0.710115
# 2019-06-22 20:06:22.013803959                        -0.862465
# 2019-06-22 20:06:22.506858110                        -0.716876
# 2019-06-22 20:06:23.006772995                        -0.827123
# 2019-06-22 20:06:23.513797998                        -0.739214
# 2019-06-22 20:06:24.032392024                        -0.772978
# 2019-06-22 20:06:39.013656139                        -0.829957
# 2019-06-22 20:06:39.522034883                        -0.828051
# 2019-06-22 20:06:40.028399944                        -0.829274
# 2019-06-22 20:06:40.508225918                        -0.830160
# 2019-06-22 20:06:41.020118952                        -0.831226
# 2019-06-22 20:06:41.505925894                        -0.831572
# 2019-06-22 20:06:42.030218840                        -0.833801
# 2019-06-22 20:06:50.513262986                        -0.887372
# 2019-06-22 20:06:51.008754969                        -0.876510
# 2019-06-22 20:06:51.515264034                        -1.019714
# 2019-06-22 20:06:52.002924919                        -0.874614
# 2019-06-22 20:07:41.015301943                        0.000061    5.0     1
# 2019-06-22 20:07:41.501550913                        0.035761    5.0     1
# 2019-06-22 20:07:42.009557962                        0.099334    5.0     1
# 2019-06-22 20:07:42.514651060                        0.140748    5.0     1
# 2019-06-22 20:07:43.001373053                        0.003712    5.0     1
# 2019-06-22 20:07:43.507714032                        0.000398    5.0     1
# 2019-06-22 20:07:44.029836893                        0.000178    5.0     1
#
#                                trial
# time
# 2019-06-22 20:06:20.514400005      0
# 2019-06-22 20:06:21.001487970      0
# 2019-06-22 20:06:21.507235050      0
# 2019-06-22 20:06:22.013803959      0
# 2019-06-22 20:06:22.506858110      0
# 2019-06-22 20:06:23.006772995      0
# 2019-06-22 20:06:23.513797998      0
# 2019-06-22 20:06:24.032392024      0
# 2019-06-22 20:06:39.013656139      1
# 2019-06-22 20:06:39.522034883      1
# 2019-06-22 20:06:40.028399944      1
# 2019-06-22 20:06:40.508225918      1
# 2019-06-22 20:06:41.020118952      1
# 2019-06-22 20:06:41.505925894      1
# 2019-06-22 20:06:42.030218840      1
# 2019-06-22 20:06:50.513262986      2
# 2019-06-22 20:06:51.008754969      2
# 2019-06-22 20:06:51.515264034      2
# 2019-06-22 20:06:52.002924919      2
# 2019-06-22 20:06:52.507894038      2
# 2019-06-22 20:06:53.014493942      2
# 2019-06-22 20:07:02.038251877      3
# 2019-06-22 20:07:02.509550095      3
# 2019-06-22 20:07:03.003628016      3
# 2019-06-22 20:07:03.510843991      3
# 2019-06-22 20:07:04.025194883      3
# 2019-06-22 20:07:04.505182981      3
# 2019-06-22 20:07:13.013777018      4
# 2019-06-22 20:07:13.521819830      4
# 2019-06-22 20:07:14.009002924      4
# 2019-06-22 20:07:14.509699106      4
# 2019-06-22 20:07:15.019208908      4
# 2019-06-22 20:07:15.505432129      4
# 2019-06-22 20:07:41.015301943      5
# 2019-06-22 20:07:41.501550913      5
# 2019-06-22 20:07:42.009557962      5
# 2019-06-22 20:07:42.514651060      5
# 2019-06-22 20:07:43.001373053      5
# 2019-06-22 20:07:43.507714032      5
# 2019-06-22 20:07:44.029836893      5

# %%
all_data_0 = all_data[all_data.label==0]
all_data_1 = all_data[all_data.label==1]
all_data_2 = all_data[all_data.label==2]
all_data_3 = all_data[all_data.label==3]
all_data_4 = all_data[all_data.label==4]
all_data_5 = all_data[all_data.label==5]

# %%
draw_col = 1

sns.distplot(all_data_0.iloc[:,draw_col], hist=False, kde=True, color='red')
sns.distplot(all_data_1.iloc[:,draw_col], hist=False, kde=True, color='green')
sns.distplot(all_data_2.iloc[:,draw_col], hist=False, kde=True, color='yellow')
sns.distplot(all_data_3.iloc[:,draw_col], hist=False, kde=True, color='pink')
sns.distplot(all_data_4.iloc[:,draw_col], hist=False, kde=True, color='blue')
sns.distplot(all_data_5.iloc[:,draw_col], hist=False, kde=True, color='black')
